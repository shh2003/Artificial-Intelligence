# %% [markdown]
# # 인공지능 개론
# ## 2주차 실습과제
# #### <csv, xls을 웹주소와 로컬 파일로 각각 읽어서 데이터프레임 작성>
#
# csv 파일: mobile.csv
#
# xls 파일: combined_dataset-1.xlsx
#
# ---

# %% [markdown]
# csv 파일 로컬에서 불러오기

# %%
import pandas as pd

csv_file = "C:/AI_File/mobile.csv"

df = pd.read_csv(csv_file)
display(df)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ---
# csv 파일 웹주소로 불러오기

# %%
import pandas as pd
csv_url = "https://raw.githubusercontent.com/MyungKyuYi/AI-class/main/mobile.csv"
df = pd.read_csv(csv_url)

display(df)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ---
# xlsx 파일 로컬에서 불러오기

# %%
import pandas as pd

xls_file = "C:/AI_File/combined_dataset-1.xlsx"

df = pd.read_excel(xls_file)
display(df)
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       1           2   Female         45         152          63
# 2       1           2   Female         45         152          63
# 3       2           3   Female         50         157          50
# 4       2           3   Female         50         157          50
# ..    ...         ...      ...        ...         ...         ...
# 652   218         418     Male         25         173          63
# 653   218         418     Male         25         173          63
# 654   219         419     Male         24         175          58
# 655   219         419     Male         24         175          58
# 656   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...

# %% [markdown]
# ---
# xlsx 파일 웹주소로 불러오기

# %%
import pandas as pd

xls_url = "https://raw.githubusercontent.com/MyungKyuYi/AI-class/main/combined_dataset-1.xlsx"
df = pd.read_excel(xls_url)

display(df)
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0       1           2   Female         45         152          63
# 1       1           2   Female         45         152          63
# 2       1           2   Female         45         152          63
# 3       2           3   Female         50         157          50
# 4       2           3   Female         50         157          50
# ..    ...         ...      ...        ...         ...         ...
# 652   218         418     Male         25         173          63
# 653   218         418     Male         25         173          63
# 654   219         419     Male         24         175          58
# 655   219         419     Male         24         175          58
# 656   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                              161                              89
# ...
